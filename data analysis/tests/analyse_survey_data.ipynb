# %%
import pandas as pd

user_data = pd.read_csv('fake_user_study_survey_data.csv')

# %%
user_data.loc[:, user_data.columns != "condition"].groupby("participant_id").mean()
# Out:
#                 Q1_mental_demand  Q2_success  Q3_frustration  \
# participant_id
# 1                       4.000000    4.000000        3.666667
# 2                       5.000000    4.333333        4.000000
# 3                       3.666667    4.666667        4.000000
# 4                       3.000000    3.333333        3.666667
# 5                       3.666667    4.333333        4.000000
# 6                       5.000000    5.000000        5.000000
# 7                       4.333333    4.666667        4.000000
# 8                       4.666667    4.000000        3.666667
# 9                       6.333333    4.000000        5.333333
# 10                      4.333333    3.333333        5.333333
# 11                      4.000000    3.333333        4.000000
# 12                      4.666667    3.333333        5.000000
# 13                      4.333333    4.000000        4.000000
# 14                      3.333333    4.666667        3.000000
# ...

# %%
8 - user_data["Q2_success"]
# Out:
# 0     2
# 1     4
# 2     6
# 3     2
# 4     4
#      ..
# 85    5
# 86    3
# 87    2
# 88    4
# 89    5
# Name: Q2_success, Length: 90, dtype: int64

# %%
user_data["overall_workload"] = (user_data["Q1_mental_demand"] + (8 - user_data["Q2_success"]) + user_data["Q3_frustration"])/3

# %%
user_data
# Out:
#     participant_id    condition  Q1_mental_demand  Q2_success  Q3_frustration  \
# 0                1  Condition_A                 2           6               1
# 1                1  Condition_B                 4           4               4
# 2                1  Condition_C                 6           2               6
# 3                2  Condition_A                 3           6               1
# 4                2  Condition_B                 5           4               4
# ..             ...          ...               ...         ...             ...
# 85              29  Condition_B                 5           3               6
# 86              29  Condition_C                 6           5               5
# 87              30  Condition_A                 1           6               1
# 88              30  Condition_B                 3           4               2
# 89              30  Condition_C                 6           3               6
#
# ...

# %%
user_data.boxplot(column="overall_workload", by="condition")
# Out:
# <Axes: title={'center': 'overall_workload'}, xlabel='condition'>

# %%
user_data.boxplot(column="Q4_trajectory_ease", by="condition")
# Out:
# <Axes: title={'center': 'Q4_trajectory_ease'}, xlabel='condition'>
