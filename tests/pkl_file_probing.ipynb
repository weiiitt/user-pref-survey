# %%
import pickle

# adjust this to your actual path
pkl_path = '../server/assets/user_study/TableTop-v0/query_tree_TableTop-v0.pkl'

with open(pkl_path, 'rb') as f:
    obj = pickle.load(f)

print(type(obj))    # e.g. dict, list, DataFrame, custom class…
print(repr(obj)[:500])  # peek at the first 500 characters
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       4 pkl_path = '../server/assets/user_study/TableTop-v0/query_tree_TableTop-v0.pkl'
#       6 with open(pkl_path, 'rb') as f:
# ----> 7     obj = pickle.load(f)
#       9 print(type(obj))    # e.g. dict, list, DataFrame, custom class…
#      10 print(repr(obj)[:500])  # peek at the first 500 characters
#
# AttributeError: Can't get attribute 'TreeNode' on <module '__main__'>
